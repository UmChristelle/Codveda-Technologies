# %% [markdown]
# # Level 1 Task 3: Basic Data Visualization
#
# This notebook creates bar, line, and scatter plots from the Iris dataset and saves the charts as image files for reporting.

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
base_dir = Path.cwd()
if not (base_dir / "data" / "iris.csv").exists():
    base_dir = Path("Task_3_Basic_Visualization")

data_path = base_dir / "data" / "iris.csv"
output_dir = base_dir / "outputs"
output_dir.mkdir(parents=True, exist_ok=True)

palette = {"setosa": "#2ecc71", "versicolor": "#3498db", "virginica": "#e74c3c"}
numeric_columns = ["sepal_length", "sepal_width", "petal_length", "petal_width"]
sns.set_theme(style="whitegrid")

# %%
df = pd.read_csv(data_path)
species_means = df.groupby("species")[numeric_columns].mean().round(3)
print("Dataset shape:", df.shape)
species_means

# %% [markdown]
# ## Bar Plot

# %%
avg_petal_length = species_means["petal_length"].reset_index()
plt.figure(figsize=(8, 5))
sns.barplot(data=avg_petal_length, x="species", y="petal_length", hue="species", palette=palette, legend=False)
plt.title("Average Petal Length by Species", fontweight="bold")
plt.xlabel("Species")
plt.ylabel("Average Petal Length (cm)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Line Chart

# %%
plt.figure(figsize=(10, 6))
for species in species_means.index:
    plt.plot(numeric_columns, species_means.loc[species, numeric_columns], marker="o", linewidth=2.5, label=species.title(), color=palette[species])
plt.title("Average Feature Values by Species", fontweight="bold")
plt.xlabel("Feature")
plt.ylabel("Average Value (cm)")
plt.legend(title="Species")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Scatter Plots

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="petal_length", y="petal_width", hue="species", palette=palette, s=80, alpha=0.85)
plt.title("Petal Length vs Petal Width", fontweight="bold")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Petal Width (cm)")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="sepal_length", y="sepal_width", hue="species", palette=palette, s=80, alpha=0.85)
plt.title("Sepal Length vs Sepal Width", fontweight="bold")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
plt.tight_layout()
plt.show()
